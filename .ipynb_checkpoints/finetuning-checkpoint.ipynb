# %% [markdown]
# # Classic Machine learning

# %% [markdown]
# ## Vision Finetuning

# %%
# !pip install fastai
from fastai.vision.all import *
# Out:
# Requirement already satisfied: fastai in ./jenv/lib/python3.10/site-packages (2.8.7)
# Requirement already satisfied: matplotlib in ./jenv/lib/python3.10/site-packages (from fastai) (3.10.8)
# Requirement already satisfied: fastcore>=1.8.0 in ./jenv/lib/python3.10/site-packages (from fastai) (1.12.38)
# Requirement already satisfied: scikit-learn in ./jenv/lib/python3.10/site-packages (from fastai) (1.7.2)
# Requirement already satisfied: plum-dispatch in ./jenv/lib/python3.10/site-packages (from fastai) (2.8.0)
# Requirement already satisfied: fastprogress>=0.2.4 in ./jenv/lib/python3.10/site-packages (from fastai) (1.1.5)
# Requirement already satisfied: fastdownload<2,>=0.0.5 in ./jenv/lib/python3.10/site-packages (from fastai) (0.0.7)
# Requirement already satisfied: packaging in ./jenv/lib/python3.10/site-packages (from fastai) (26.0)
# Requirement already satisfied: fasttransform>=0.0.2 in ./jenv/lib/python3.10/site-packages (from fastai) (0.0.2)
# Requirement already satisfied: scipy in ./jenv/lib/python3.10/site-packages (from fastai) (1.15.3)
# Requirement already satisfied: requests in ./jenv/lib/python3.10/site-packages (from fastai) (2.33.1)
# Requirement already satisfied: spacy<4 in ./jenv/lib/python3.10/site-packages (from fastai) (3.8.14)
# Requirement already satisfied: cloudpickle in ./jenv/lib/python3.10/site-packages (from fastai) (3.1.2)
# Requirement already satisfied: torch<3,>=1.10 in ./jenv/lib/python3.10/site-packages (from fastai) (2.11.0)
# Requirement already satisfied: pyyaml in ./jenv/lib/python3.10/site-packages (from fastai) (6.0.3)
# Requirement already satisfied: pandas in ./jenv/lib/python3.10/site-packages (from fastai) (2.3.3)
# Requirement already satisfied: pillow>=9.0.0 in ./jenv/lib/python3.10/site-packages (from fastai) (12.2.0)
# Requirement already satisfied: torchvision>=0.11 in ./jenv/lib/python3.10/site-packages (from fastai) (0.26.0)
# Requirement already satisfied: python-fasthtml>=0.12.34 in ./jenv/lib/python3.10/site-packages (from fastprogress>=0.2.4->fastai) (0.13.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in ./jenv/lib/python3.10/site-packages (from spacy<4->fastai) (3.0.12)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in ./jenv/lib/python3.10/site-packages (from spacy<4->fastai) (1.0.15)
# Requirement already satisfied: setuptools in ./jenv/lib/python3.10/site-packages (from spacy<4->fastai) (65.5.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in ./jenv/lib/python3.10/site-packages (from spacy<4->fastai) (1.0.5)
# Requirement already satisfied: confection<2.0.0,>=1.3.2 in ./jenv/lib/python3.10/site-packages (from spacy<4->fastai) (1.3.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in ./jenv/lib/python3.10/site-packages (from spacy<4->fastai) (2.0.13)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in ./jenv/lib/python3.10/site-packages (from spacy<4->fastai) (4.67.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in ./jenv/lib/python3.10/site-packages (from spacy<4->fastai) (2.0.10)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in ./jenv/lib/python3.10/site-packages (from spacy<4->fastai) (2.12.5)
# Requirement already satisfied: numpy>=1.19.0 in ./jenv/lib/python3.10/site-packages (from spacy<4->fastai) (2.2.6)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in ./jenv/lib/python3.10/site-packages (from spacy<4->fastai) (0.24.1)
# Requirement already satisfied: jinja2 in ./jenv/lib/python3.10/site-packages (from spacy<4->fastai) (3.1.6)
# Requirement already satisfied: weasel<2.0.0,>=1.0.0 in ./jenv/lib/python3.10/site-packages (from spacy<4->fastai) (1.0.0)
# Requirement already satisfied: thinc<8.4.0,>=8.3.12 in ./jenv/lib/python3.10/site-packages (from spacy<4->fastai) (8.3.13)
# Requirement already satisfied: srsly<3.0.0,>=2.5.3 in ./jenv/lib/python3.10/site-packages (from spacy<4->fastai) (2.5.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in ./jenv/lib/python3.10/site-packages (from spacy<4->fastai) (1.1.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in ./jenv/lib/python3.10/site-packages (from spacy<4->fastai) (3.0.13)
# Requirement already satisfied: idna<4,>=2.5 in ./jenv/lib/python3.10/site-packages (from requests->fastai) (3.11)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./jenv/lib/python3.10/site-packages (from requests->fastai) (3.4.7)
# Requirement already satisfied: certifi>=2023.5.7 in ./jenv/lib/python3.10/site-packages (from requests->fastai) (2026.2.25)
# Requirement already satisfied: urllib3<3,>=1.26 in ./jenv/lib/python3.10/site-packages (from requests->fastai) (2.6.3)
# Requirement already satisfied: sympy>=1.13.3 in ./jenv/lib/python3.10/site-packages (from torch<3,>=1.10->fastai) (1.14.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in ./jenv/lib/python3.10/site-packages (from torch<3,>=1.10->fastai) (4.15.0)
# Requirement already satisfied: filelock in ./jenv/lib/python3.10/site-packages (from torch<3,>=1.10->fastai) (3.25.2)
# Requirement already satisfied: fsspec>=0.8.5 in ./jenv/lib/python3.10/site-packages (from torch<3,>=1.10->fastai) (2026.3.0)
# Requirement already satisfied: networkx>=2.5.1 in ./jenv/lib/python3.10/site-packages (from torch<3,>=1.10->fastai) (3.4.2)
# Requirement already satisfied: pyparsing>=3 in ./jenv/lib/python3.10/site-packages (from matplotlib->fastai) (3.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in ./jenv/lib/python3.10/site-packages (from matplotlib->fastai) (4.62.1)
# Requirement already satisfied: contourpy>=1.0.1 in ./jenv/lib/python3.10/site-packages (from matplotlib->fastai) (1.3.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./jenv/lib/python3.10/site-packages (from matplotlib->fastai) (1.5.0)
# Requirement already satisfied: python-dateutil>=2.7 in ./jenv/lib/python3.10/site-packages (from matplotlib->fastai) (2.9.0.post0)
# Requirement already satisfied: cycler>=0.10 in ./jenv/lib/python3.10/site-packages (from matplotlib->fastai) (0.12.1)
# Requirement already satisfied: tzdata>=2022.7 in ./jenv/lib/python3.10/site-packages (from pandas->fastai) (2026.1)
# Requirement already satisfied: pytz>=2020.1 in ./jenv/lib/python3.10/site-packages (from pandas->fastai) (2026.1.post1)
# Requirement already satisfied: rich>=10.0 in ./jenv/lib/python3.10/site-packages (from plum-dispatch->fastai) (14.3.4)
# Requirement already satisfied: beartype>=0.16.2 in ./jenv/lib/python3.10/site-packages (from plum-dispatch->fastai) (0.22.9)
# Requirement already satisfied: joblib>=1.2.0 in ./jenv/lib/python3.10/site-packages (from scikit-learn->fastai) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./jenv/lib/python3.10/site-packages (from scikit-learn->fastai) (3.6.0)
# Requirement already satisfied: annotated-types>=0.6.0 in ./jenv/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.0.0->spacy<4->fastai) (0.7.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in ./jenv/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.0.0->spacy<4->fastai) (0.4.2)
# Requirement already satisfied: pydantic-core==2.41.5 in ./jenv/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.0.0->spacy<4->fastai) (2.41.5)
# Requirement already satisfied: six>=1.5 in ./jenv/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->fastai) (1.17.0)
# Requirement already satisfied: uvicorn[standard]>=0.30 in ./jenv/lib/python3.10/site-packages (from python-fasthtml>=0.12.34->fastprogress>=0.2.4->fastai) (0.44.0)
# Requirement already satisfied: itsdangerous in ./jenv/lib/python3.10/site-packages (from python-fasthtml>=0.12.34->fastprogress>=0.2.4->fastai) (2.2.0)
# Requirement already satisfied: httpx in ./jenv/lib/python3.10/site-packages (from python-fasthtml>=0.12.34->fastprogress>=0.2.4->fastai) (0.28.1)
# Requirement already satisfied: beautifulsoup4 in ./jenv/lib/python3.10/site-packages (from python-fasthtml>=0.12.34->fastprogress>=0.2.4->fastai) (4.14.3)
# Requirement already satisfied: starlette~=1.0 in ./jenv/lib/python3.10/site-packages (from python-fasthtml>=0.12.34->fastprogress>=0.2.4->fastai) (1.0.0)
# Requirement already satisfied: python-multipart in ./jenv/lib/python3.10/site-packages (from python-fasthtml>=0.12.34->fastprogress>=0.2.4->fastai) (0.0.26)
# Requirement already satisfied: oauthlib in ./jenv/lib/python3.10/site-packages (from python-fasthtml>=0.12.34->fastprogress>=0.2.4->fastai) (3.3.1)
# Requirement already satisfied: fastlite>=0.1.1 in ./jenv/lib/python3.10/site-packages (from python-fasthtml>=0.12.34->fastprogress>=0.2.4->fastai) (0.2.4)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./jenv/lib/python3.10/site-packages (from rich>=10.0->plum-dispatch->fastai) (2.20.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./jenv/lib/python3.10/site-packages (from rich>=10.0->plum-dispatch->fastai) (4.0.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./jenv/lib/python3.10/site-packages (from sympy>=1.13.3->torch<3,>=1.10->fastai) (1.3.0)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in ./jenv/lib/python3.10/site-packages (from thinc<8.4.0,>=8.3.12->spacy<4->fastai) (1.3.3)
# Requirement already satisfied: click>=8.2.1 in ./jenv/lib/python3.10/site-packages (from typer<1.0.0,>=0.3.0->spacy<4->fastai) (8.3.2)
# Requirement already satisfied: shellingham>=1.3.0 in ./jenv/lib/python3.10/site-packages (from typer<1.0.0,>=0.3.0->spacy<4->fastai) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in ./jenv/lib/python3.10/site-packages (from typer<1.0.0,>=0.3.0->spacy<4->fastai) (0.0.4)
# Requirement already satisfied: cloudpathlib>=0.7.0 in ./jenv/lib/python3.10/site-packages (from weasel<2.0.0,>=1.0.0->spacy<4->fastai) (0.23.0)
# Requirement already satisfied: smart-open>=5.2.1 in ./jenv/lib/python3.10/site-packages (from weasel<2.0.0,>=1.0.0->spacy<4->fastai) (7.5.1)
# Requirement already satisfied: MarkupSafe>=2.0 in ./jenv/lib/python3.10/site-packages (from jinja2->spacy<4->fastai) (3.0.3)
# Requirement already satisfied: apswutils>=0.1.2 in ./jenv/lib/python3.10/site-packages (from fastlite>=0.1.1->python-fasthtml>=0.12.34->fastprogress>=0.2.4->fastai) (0.1.2)
# Requirement already satisfied: anyio in ./jenv/lib/python3.10/site-packages (from httpx->python-fasthtml>=0.12.34->fastprogress>=0.2.4->fastai) (4.13.0)
# Requirement already satisfied: httpcore==1.* in ./jenv/lib/python3.10/site-packages (from httpx->python-fasthtml>=0.12.34->fastprogress>=0.2.4->fastai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in ./jenv/lib/python3.10/site-packages (from httpcore==1.*->httpx->python-fasthtml>=0.12.34->fastprogress>=0.2.4->fastai) (0.16.0)
# Requirement already satisfied: mdurl~=0.1 in ./jenv/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=10.0->plum-dispatch->fastai) (0.1.2)
# Requirement already satisfied: wrapt in ./jenv/lib/python3.10/site-packages (from smart-open>=5.2.1->weasel<2.0.0,>=1.0.0->spacy<4->fastai) (2.1.2)
# Requirement already satisfied: uvloop>=0.15.1 in ./jenv/lib/python3.10/site-packages (from uvicorn[standard]>=0.30->python-fasthtml>=0.12.34->fastprogress>=0.2.4->fastai) (0.22.1)
# Requirement already satisfied: httptools>=0.6.3 in ./jenv/lib/python3.10/site-packages (from uvicorn[standard]>=0.30->python-fasthtml>=0.12.34->fastprogress>=0.2.4->fastai) (0.7.1)
# Requirement already satisfied: websockets>=10.4 in ./jenv/lib/python3.10/site-packages (from uvicorn[standard]>=0.30->python-fasthtml>=0.12.34->fastprogress>=0.2.4->fastai) (16.0)
# Requirement already satisfied: watchfiles>=0.20 in ./jenv/lib/python3.10/site-packages (from uvicorn[standard]>=0.30->python-fasthtml>=0.12.34->fastprogress>=0.2.4->fastai) (1.1.1)
# Requirement already satisfied: python-dotenv>=0.13 in ./jenv/lib/python3.10/site-packages (from uvicorn[standard]>=0.30->python-fasthtml>=0.12.34->fastprogress>=0.2.4->fastai) (1.2.2)
# Requirement already satisfied: soupsieve>=1.6.1 in ./jenv/lib/python3.10/site-packages (from beautifulsoup4->python-fasthtml>=0.12.34->fastprogress>=0.2.4->fastai) (2.8.3)
# Requirement already satisfied: exceptiongroup>=1.0.2 in ./jenv/lib/python3.10/site-packages (from anyio->httpx->python-fasthtml>=0.12.34->fastprogress>=0.2.4->fastai) (1.3.1)
# Requirement already satisfied: apsw in ./jenv/lib/python3.10/site-packages (from apswutils>=0.1.2->fastlite>=0.1.1->python-fasthtml>=0.12.34->fastprogress>=0.2.4->fastai) (3.53.0.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
path = untar_data(URLs.PETS)
path.ls()
# Out:
# Downloading a new version of this dataset...
# <div><progress max="811706944" value="811712512"></progress> 100.00% [811712512/811706944 02:39&lt;00:00]</div>
# [Path('/Users/Yashwanth.B/.fastai/data/oxford-iiit-pet/images'), Path('/Users/Yashwanth.B/.fastai/data/oxford-iiit-pet/annotations')]

# %%
print(path)
# Out:
# /Users/Yashwanth.B/.fastai/data/oxford-iiit-pet

# %%
image_path = path/"images/test.png"
image_path.exists()
# Out:
# True

# %%
def label_func(f): return f[0].isupper()
dls = ImageDataLoaders.from_name_func(path, files, label_func, item_tfms=Resize(224))
dls.show_batch()

# %%
learner = vision_learner(dls, resnet34, metrics=error_rate)
learner.fine_tune(1)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-b627a593.pth" to /Users/Yashwanth.B/.cache/torch/hub/checkpoints/resnet34-b627a593.pth
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████| 83.3M/83.3M [00:12<00:00, 6.97MB/s]
# <div><table class="fastprogress"><thead><tr><th>epoch</th><th>train_loss</th><th>valid_loss</th><th>error_rate</th><th>time</th></tr></thead><tbody><tr><td>0</td><td>0.140785</td><td>0.012256</td><td>0.003383</td><td>00:46</td></tr></tbody></table></div>
# <div><table class="fastprogress"><thead><tr><th>epoch</th><th>train_loss</th><th>valid_loss</th><th>error_rate</th><th>time</th></tr></thead><tbody><tr><td>0</td><td>0.055216</td><td>0.013536</td><td>0.004736</td><td>00:55</td></tr></tbody></table></div>

# %%
output = learner.predict(path/"images/British_Shorthair_21.jpg")
print(output)
# Out:
# ('True', tensor(1), tensor([2.3438e-21, 1.0000e+00]))

# %%
learner.show_results()

# %%
## Classification Finetuning

# %%
path = untar_data(URLs.IMDB)
path.ls()
# Out:
# <div><progress max="144440600" value="144441344"></progress> 100.00% [144441344/144440600 00:27&lt;00:00]</div>
# [Path('/Users/Yashwanth.B/.fastai/data/imdb/test'), Path('/Users/Yashwanth.B/.fastai/data/imdb/tmp_clas'), Path('/Users/Yashwanth.B/.fastai/data/imdb/imdb.vocab'), Path('/Users/Yashwanth.B/.fastai/data/imdb/unsup'), Path('/Users/Yashwanth.B/.fastai/data/imdb/README'), Path('/Users/Yashwanth.B/.fastai/data/imdb/tmp_lm'), Path('/Users/Yashwanth.B/.fastai/data/imdb/train')]
