# %%
from fastai.vision.all import *

# %%
path = untar_data(URLs.PETS)

# %%
files = get_image_files(path)

# %%
def get_label(f): return f[0].isupper()
dls = ImageDataLoaders.from_name_func(path/'images', files, get_label, item_tfms=Resize(224))

# %%
learner = vision_learner(dls,resnet18, metrics=[accuracy, error_rate])

# %%
plot = learner.lr_find(suggest_funcs=(valley))
# Out:
# <div></div>

# %%
learner.fine_tune(1, plot.valley)
# Out:
# <div><table class="fastprogress"><thead><tr><th>epoch</th><th>train_loss</th><th>valid_loss</th><th>accuracy</th><th>error_rate</th><th>time</th></tr></thead><tbody><tr><td>0</td><td>0.455738</td><td>0.266013</td><td>0.880244</td><td>0.119756</td><td>01:00</td></tr></tbody></table></div>
# <div><table class="fastprogress"><thead><tr><th>epoch</th><th>train_loss</th><th>valid_loss</th><th>accuracy</th><th>error_rate</th><th>time</th></tr></thead><tbody><tr><td>0</td><td>0.260202</td><td>0.175275</td><td>0.924899</td><td>0.075101</td><td>01:20</td></tr></tbody></table></div>

# %%
learner.predict(files[1])
# Out:
# ('False', tensor(0), tensor([0.9976, 0.0024]))
