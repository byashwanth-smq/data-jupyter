# %% [markdown]
# ## Logistics regression using HR columsn

# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/Yashwanth.B/jupyter/datasets/HR_comma_sep.csv")
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   3              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# ...

# %%
columns_top_drop = ["last_evaluation", "Work_accident"]
df = df.drop(columns=columns_top_drop)
df.head()
# Out:
#    satisfaction_level  number_project  average_montly_hours  \
# 0                0.38               2                   157
# 1                0.80               5                   262
# 2                0.11               7                   272
# 3                0.72               5                   223
# 4                0.37               2                   159
#
#    time_spend_company  left  promotion_last_5years Department  salary
# 0                   3     1                      0      sales     low
# 1                   6     1                      0      sales  medium
# 2                   4     1                      0      sales  medium
# 3                   5     1                      0      sales     low
# 4                   3     1                      0      sales     low

# %% [markdown]
# ### Basic quantile outlier filter

# %%
quantile_filters = ["satisfaction_level", "average_montly_hours", "time_spend_company"]
for quantile_filter in quantile_filters:
    min_threshold = df[quantile_filter].quantile(0.05)
    max_threshold = df[quantile_filter].quantile(0.95)
    df = df[(df[quantile_filter] > min_threshold) & (df[quantile_filter] < max_threshold)]

# %%
df.shape
# Out:
# (8134, 8)

# %%
print(df["average_montly_hours"].skew())
print(df["satisfaction_level"].skew())
# Out:
# 0.1859973306216951
# -0.350986862465508

# %% [markdown]
# ### hot encoding

# %%
categories = ["Department", "salary"]
for category in categories:
    splitted_categories = pd.get_dummies(df[category], prefix=category)
    df = pd.concat([df, splitted_categories], axis=1)
df = df.drop(columns=categories)
df.head()
# Out:
#    satisfaction_level  number_project  average_montly_hours  \
# 0                0.38               2                   157
# 3                0.72               5                   223
# 4                0.37               2                   159
# 5                0.41               2                   153
# 7                0.92               5                   259
#
#    time_spend_company  left  promotion_last_5years  Department_IT  \
# 0                   3     1                      0          False
# 3                   5     1                      0          False
# 4                   3     1                      0          False
# 5                   3     1                      0          False
# 7                   5     1                      0          False
#
#    Department_RandD  Department_accounting  Department_hr  \
# 0             False                  False          False
# 3             False                  False          False
# ...

# %%
df
# Out:
#        satisfaction_level  number_project  average_montly_hours  \
# 0                    0.38               2                   157
# 3                    0.72               5                   223
# 4                    0.37               2                   159
# 5                    0.41               2                   153
# 7                    0.92               5                   259
# ...                   ...             ...                   ...
# 14992                0.40               2                   155
# 14994                0.40               2                   151
# 14995                0.37               2                   160
# 14996                0.37               2                   143
# 14998                0.37               2                   158
#
#        time_spend_company  left  promotion_last_5years  Department_IT  \
# 0                       3     1                      0          False
# ...

# %%
df.columns
# Out:
# Index(['satisfaction_level', 'number_project', 'average_montly_hours',
#        'time_spend_company', 'left', 'promotion_last_5years', 'Department_IT',
#        'Department_RandD', 'Department_accounting', 'Department_hr',
#        'Department_management', 'Department_marketing',
#        'Department_product_mng', 'Department_sales', 'Department_support',
#        'Department_technical', 'salary_high', 'salary_low', 'salary_medium'],
#       dtype='object')

# %%
df.head()
# Out:
#    satisfaction_level  number_project  average_montly_hours  \
# 0                0.38               2                   157
# 3                0.72               5                   223
# 4                0.37               2                   159
# 5                0.41               2                   153
# 7                0.92               5                   259
#
#    time_spend_company  left  promotion_last_5years  Department_IT  \
# 0                   3     1                      0          False
# 3                   5     1                      0          False
# 4                   3     1                      0          False
# 5                   3     1                      0          False
# 7                   5     1                      0          False
#
#    Department_RandD  Department_accounting  Department_hr  \
# 0             False                  False          False
# 3             False                  False          False
# ...

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
x = df.drop(columns=['left'])
y = df['left']
model.fit(x, y)
# Out:
# /Users/Yashwanth.B/jupyter/jenv/lib/python3.10/site-packages/sklearn/linear_model/_linear_loss.py:200: RuntimeWarning: divide by zero encountered in matmul
#   raw_prediction = X @ weights + intercept
# /Users/Yashwanth.B/jupyter/jenv/lib/python3.10/site-packages/sklearn/linear_model/_linear_loss.py:200: RuntimeWarning: overflow encountered in matmul
#   raw_prediction = X @ weights + intercept
# /Users/Yashwanth.B/jupyter/jenv/lib/python3.10/site-packages/sklearn/linear_model/_linear_loss.py:200: RuntimeWarning: invalid value encountered in matmul
#   raw_prediction = X @ weights + intercept
# /Users/Yashwanth.B/jupyter/jenv/lib/python3.10/site-packages/sklearn/linear_model/_linear_loss.py:330: RuntimeWarning: divide by zero encountered in matmul
#   grad[:n_features] = X.T @ grad_pointwise + l2_reg_strength * weights
# /Users/Yashwanth.B/jupyter/jenv/lib/python3.10/site-packages/sklearn/linear_model/_linear_loss.py:330: RuntimeWarning: overflow encountered in matmul
# ...

# %%
df.columns
# Out:
# Index(['satisfaction_level', 'number_project', 'average_montly_hours',
#        'time_spend_company', 'left', 'promotion_last_5years', 'Department_IT',
#        'Department_RandD', 'Department_accounting', 'Department_hr',
#        'Department_management', 'Department_marketing',
#        'Department_product_mng', 'Department_sales', 'Department_support',
#        'Department_technical', 'salary_high', 'salary_low', 'salary_medium'],
#       dtype='object')

# %%
print(x.isnull().sum())
# Out:
# satisfaction_level        0
# number_project            0
# average_montly_hours      0
# time_spend_company        0
# promotion_last_5years     0
# Department_IT             0
# Department_RandD          0
# Department_accounting     0
# Department_hr             0
# Department_management     0
# Department_marketing      0
# Department_product_mng    0
# Department_sales          0
# Department_support        0
# Department_technical      0
# salary_high               0
# salary_low                0
# salary_medium             0
# dtype: int64

# %%
df.head()
# Out:
#    satisfaction_level  number_project  average_montly_hours  \
# 0                0.38               2                   157
# 3                0.72               5                   223
# 4                0.37               2                   159
# 5                0.41               2                   153
# 7                0.92               5                   259
#
#    time_spend_company  left  promotion_last_5years  Department_IT  \
# 0                   3     1                      0          False
# 3                   5     1                      0          False
# 4                   3     1                      0          False
# 5                   3     1                      0          False
# 7                   5     1                      0          False
#
#    Department_RandD  Department_accounting  Department_hr  \
# 0             False                  False          False
# 3             False                  False          False
# ...

# %%
df['predict_left'] = model.predict(df.drop(columns=['left']))
# Out:
# /Users/Yashwanth.B/jupyter/jenv/lib/python3.10/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/Yashwanth.B/jupyter/jenv/lib/python3.10/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/Yashwanth.B/jupyter/jenv/lib/python3.10/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b

# %%
df.head()
# Out:
#    satisfaction_level  number_project  average_montly_hours  \
# 0                0.38               2                   157
# 3                0.72               5                   223
# 4                0.37               2                   159
# 5                0.41               2                   153
# 7                0.92               5                   259
#
#    time_spend_company  left  promotion_last_5years  Department_IT  \
# 0                   3     1                      0          False
# 3                   5     1                      0          False
# 4                   3     1                      0          False
# 5                   3     1                      0          False
# 7                   5     1                      0          False
#
#    Department_RandD  Department_accounting  Department_hr  \
# 0             False                  False          False
# 3             False                  False          False
# ...

# %%
df.to_csv('predict_hr.csv', index=False)

# %% [markdown]
# ### Evaluation

# %%
model.score(x, y)
# Out:
# /Users/Yashwanth.B/jupyter/jenv/lib/python3.10/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/Yashwanth.B/jupyter/jenv/lib/python3.10/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/Yashwanth.B/jupyter/jenv/lib/python3.10/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# 0.8174329972953036
